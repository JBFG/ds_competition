# %%
from jbfg.pandas_utils import *

# %%
schema = 'l2_jbbk_extnl'

# %%
sql='select * from products_info'

# %%
products_info=get_df(sql,schema)
products_info
# Out:
#    product_id                                               name category_id  \
# 0       21709                              Sparkling Lemon Water         115
# 1       20995                           Organic Broccoli Florets         116
# 2       33000                                  Pure Irish Butter          36
# 3        7781  Organic Sticks Low Moisture Part Skim Mozzarel...          21
# 4       47144     Unsweetened Original Almond Breeze Almond Milk          91
# ..        ...                                                ...         ...
# 95      47209                               Organic Hass Avocado          24
# 96      21903                               Organic Baby Spinach         123
# 97      21137                               Organic Strawberries          24
# 98      13176                             Bag of Organic Bananas          24
# 99      24852                                             Banana          24
#
#    division_id                  category_name division_name
# 0            7  water seltzer sparkling water     beverages
# 1            1                 frozen produce        frozen
# 2           16                         butter    dairy eggs
# 3           16                packaged cheese    dairy eggs
# 4           16                soy lactosefree    dairy eggs
# ..         ...                            ...           ...
# 95           4                   fresh fruits       produce
# 96           4     packaged vegetables fruits       produce
# 97           4                   fresh fruits       produce
# 98           4                   fresh fruits       produce
# 99           4                   fresh fruits       produce
#
# [100 rows x 6 columns]

# %%
sql='select * from train_x_past'
train_x_past=get_df(sql,schema)
train_x_past
# Out:
#         order_id   cstno order_number week_day order_hour order_interval  \
# 0         717029  196613           15        1          9            3.0
# 1        2325772  196613           35        6         11            2.0
# 2         642668  196613           69        2         16            2.0
# 3        1326515  196613           61        3         19            3.0
# 4        1437845  196613           36        3         15            4.0
# ...          ...     ...          ...      ...        ...            ...
# 1253967  1902783  163819           47        0         19           13.0
# 1253968  1969590  163819           42        1         15            6.0
# 1253969  2549215  163819            9        1         11            7.0
# 1253970  3103211  163819           39        1         14            7.0
# 1253971  3207262  163819            8        1         12            7.0
#
#         add_order is_reordered product_id
# 0               5            0      41220
# 1               7            1      41220
# 2              11            1       4210
# 3               3            1       4210
# 4              16            0       4210
# ...           ...          ...        ...
# 1253967         2            1      24852
# 1253968         3            1      24852
# 1253969         1            1      24852
# 1253970         3            1      24852
# 1253971         1            1      24852
#
# [1253972 rows x 9 columns]

# %%
sql='select * from train_x_current'
train_x_current=get_df(sql,schema)
train_x_current
# Out:
#       order_id   cstno order_number week_day order_hour order_interval  \
# 0       806422   41116           47        5         18            3.0
# 1      2146033  127113           45        1         10            7.0
# 2      3055498  140168           45        5         10           26.0
# 3      3267527   60604           52        0         16            8.0
# 4      3125992  136554           46        4          9            5.0
# ...        ...     ...          ...      ...        ...            ...
# 24419  3184000  174046          100        5          7            2.0
# 24420  1754722    6710          100        5         11            3.0
# 24421  1076973  150840          100        0         13            0.0
# 24422  1247049   99707          100        1         13            3.0
# 24423  1775787  201038          100        5          9            2.0
#
#       add_order is_reordered
# 0             4            1
# 1            24            1
# 2            11            1
# 3             2            1
# 4             2            0
# ...         ...          ...
# 24419        12            1
# 24420        21            1
# 24421        18            1
# 24422         6            1
# 24423         1            1
#
# [24424 rows x 8 columns]

# %%
sql='select * from train_y'
train_y=get_df(sql,schema)
train_y
# Out:
#       product_id
# 0          21709
# 1          21709
# 2          21709
# 3          21709
# 4          21709
# ...          ...
# 24419      24852
# 24420      24852
# 24421      24852
# 24422      24852
# 24423      24852
#
# [24424 rows x 1 columns]

# %%
sql='select * from test_x_past'
test_x_past=get_df(sql,schema)
test_x_past
# Out:
#        order_id   cstno order_number week_day order_hour order_interval  \
# 0        117004  186630           37        4         11            3.0
# 1        128658  186630           20        2         10            6.0
# 2        165882  186630           56        3         15            5.0
# 3        180165  186630           17        1         16            4.0
# 4        394948  186630           46        5         11            7.0
# ...         ...     ...          ...      ...        ...            ...
# 541917  2672845  119134           39        1         14           17.0
# 541918  2731678  119134           38        5         14            3.0
# 541919  2860406  119134            9        5          9            8.0
# 541920  3252013  119134            4        5         10            7.0
# 541921  3275894  119134           16        4         10            3.0
#
#        add_order is_reordered product_id
# 0             12            1      21709
# 1              4            1      21709
# 2             10            1      21709
# 3              4            1      21709
# 4              7            1      21709
# ...          ...          ...        ...
# 541917         4            1      24852
# 541918         4            1      24852
# 541919         1            1      24852
# 541920         2            1      24852
# 541921        10            1      24852
#
# [541922 rows x 9 columns]

# %%
sql='select * from test_x_current'
test_x_current=get_df(sql,schema)
test_x_current
# Out:
#       order_id   cstno order_number week_day order_hour order_interval  \
# 0      3384204   37987           38        5         16           13.0
# 1      2578612  169022           38        6         10            7.0
# 2       188887  200090           45        5         16           30.0
# 3       646772  149416           39        1         13           13.0
# 4       300214  113836           42        3         10           17.0
# ...        ...     ...          ...      ...        ...            ...
# 16121  2047884   57077           46        5         15            8.0
# 16122   567625   83592           43        4         12            0.0
# 16123   596442  157740           49        6         10            3.0
# 16124   671102   92043           43        4         10           10.0
# 16125   529654   62871           58        4          8            8.0
#
#       add_order is_reordered
# 0             9            1
# 1             4            1
# 2             5            1
# 3            15            1
# 4             1            1
# ...         ...          ...
# 16121         2            1
# 16122         1            1
# 16123         2            1
# 16124         1            1
# 16125        22            1
#
# [16126 rows x 8 columns]

# %% [markdown]
# # 온라인 상점 재구매률 제고 방안 프로젝트
#
# <br>
#
# 온라인 상점의 재구무률 제고 방안을 도출하기 위해서는 다음과 같은 분석 순서로 진행 예정입니다.
# <ul>
# <li>1. 데이터 분석</li>
#     <ul>
#     <li>1.1 데이터 구조 파악</li>
#     <li>1.2 데이터 전처리 작업</li>
#     <li>1.3 데이터 분석 </li>
#     </ul>
#     <br>
# <li>2. 예측 모델 개발</li>
#     <ul>
#     <li>2.1 고객분류</li>
#         <ul>
#         <li>2.1.1 RFM 분석</li>
#         <li>2.1.2 고객 세분화(K Mean 활용)</li>
#         </ul>
#     <li>2.2 Association Rule Mining 실시</li>
#     <li>2.3 모델 결정</li>
#     </ul>
#     <br>
# <li>3. 결과 검증</li>
# </ul>

# %% [markdown]
# ## 1. 데이터 분석

# %% [markdown]
# ### 1.1 데이터 구조파악

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

import os 

color = sns.color_palette()

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1.2 데이터 전처리 작업

# %%
train_past = pd.merge(train_x_past,products_info, on=['product_id','product_id'])
train_past.head()
# Out:
#   order_id   cstno order_number week_day order_hour order_interval add_order  \
# 0   717029  196613           15        1          9            3.0         5
# 1  2325772  196613           35        6         11            2.0         7
# 2    71041   32780           26        6         14            1.0         1
# 3  1265600   65610           29        5         13           12.0         3
# 4  1338494   65610           37        3         19            3.0         2
#
#   is_reordered product_id                     name category_id division_id  \
# 0            0      41220  Organic Romaine Lettuce          83           4
# 1            1      41220  Organic Romaine Lettuce          83           4
# 2            0      41220  Organic Romaine Lettuce          83           4
# 3            1      41220  Organic Romaine Lettuce          83           4
# 4            1      41220  Organic Romaine Lettuce          83           4
#
#       category_name division_name
# 0  fresh vegetables       produce
# 1  fresh vegetables       produce
# 2  fresh vegetables       produce
# 3  fresh vegetables       produce
# 4  fresh vegetables       produce

# %%
train_past.isna().sum(axis = 0)
# Out:
# order_id          0
# cstno             0
# order_number      0
# week_day          0
# order_hour        0
# order_interval    0
# add_order         0
# is_reordered      0
# product_id        0
# name              0
# category_id       0
# division_id       0
# category_name     0
# division_name     0
# dtype: int64

# %%
train_past.rename(columns = {'name': 'product_name'},inplace=True)
train_past
# Out:
#         order_id   cstno order_number week_day order_hour order_interval  \
# 0         717029  196613           15        1          9            3.0
# 1        2325772  196613           35        6         11            2.0
# 2          71041   32780           26        6         14            1.0
# 3        1265600   65610           29        5         13           12.0
# 4        1338494   65610           37        3         19            3.0
# ...          ...     ...          ...      ...        ...            ...
# 1253967  3396218   98204           30        5          8            7.0
# 1253968   432471  163746           33        5          7            5.0
# 1253969  1822814  163746           31        5          8           19.0
# 1253970  3160609  196534           31        6         13            4.0
# 1253971    71274  163782           16        0         12            5.0
#
#         add_order is_reordered product_id             product_name  \
# 0               5            0      41220  Organic Romaine Lettuce
# 1               7            1      41220  Organic Romaine Lettuce
# 2               1            0      41220  Organic Romaine Lettuce
# 3               3            1      41220  Organic Romaine Lettuce
# 4               2            1      41220  Organic Romaine Lettuce
# ...           ...          ...        ...                      ...
# 1253967         2            1      11520      Large Alfresco Eggs
# 1253968         1            1      11520      Large Alfresco Eggs
# 1253969         2            0      11520      Large Alfresco Eggs
# 1253970        11            0      11520      Large Alfresco Eggs
# 1253971         1            0      11520      Large Alfresco Eggs
#
#         category_id division_id     category_name division_name
# 0                83           4  fresh vegetables       produce
# 1                83           4  fresh vegetables       produce
# 2                83           4  fresh vegetables       produce
# 3                83           4  fresh vegetables       produce
# 4                83           4  fresh vegetables       produce
# ...             ...         ...               ...           ...
# 1253967          86          16              eggs    dairy eggs
# 1253968          86          16              eggs    dairy eggs
# 1253969          86          16              eggs    dairy eggs
# 1253970          86          16              eggs    dairy eggs
# 1253971          86          16              eggs    dairy eggs
#
# [1253972 rows x 14 columns]

# %% [markdown]
# ### 1.3 데이터 분석

# %% [markdown]
# #### 1.3.1 판매된 상품 및 부서 분석

# %% [markdown]
# <font size="3"> <b> Q. 상품판매 순위 </font>

# %% [markdown]
# <b> Q 1. 개별 상품별 분석

# %%
cnt_prd = train_past['product_name'].value_counts().reset_index()
cnt_prd.columns = ['product_name', 'frequency_count']
cnt_prd
# Out:
#                                       product_name  frequency_count
# 0                                           Banana            74686
# 1                           Bag of Organic Bananas            67514
# 2                             Organic Strawberries            52917
# 3                             Organic Hass Avocado            42604
# 4                             Organic Baby Spinach            40112
# ..                                             ...              ...
# 95                                          Garlic             4210
# 96  Unsweetened Original Almond Breeze Almond Milk             4122
# 97                                     Roma Tomato             3829
# 98                             2% Reduced Fat Milk             3547
# 99                                            Soda             2712
#
# [100 rows x 2 columns]

# %%
# 상품별 누적비중산출 
cnt_prd['cum_percent'] = 100*(cnt_prd['frequency_count'].cumsum() / cnt_prd['frequency_count'].sum())


# 상품별 비중산출
cnt_prd['percent'] = 100*(cnt_prd['frequency_count'] / cnt_prd['frequency_count'].sum())

cnt_prd
# Out:
#                                       product_name  frequency_count  \
# 0                                           Banana            74686
# 1                           Bag of Organic Bananas            67514
# 2                             Organic Strawberries            52917
# 3                             Organic Hass Avocado            42604
# 4                             Organic Baby Spinach            40112
# ..                                             ...              ...
# 95                                          Garlic             4210
# 96  Unsweetened Original Almond Breeze Almond Milk             4122
# 97                                     Roma Tomato             3829
# 98                             2% Reduced Fat Milk             3547
# 99                                            Soda             2712
#
#     cum_percent   percent
# 0      5.955954  5.955954
# 1     11.339966  5.384012
# 2     15.559917  4.219951
# 3     18.957441  3.397524
# 4     22.156236  3.198796
# ..          ...       ...
# 95    98.866801  0.335733
# 96    99.195516  0.328715
# 97    99.500866  0.305350
# 98    99.783727  0.282861
# 99   100.000000  0.216273
#
# [100 rows x 4 columns]

# %%
cnt_prd_sub=cnt_prd.loc[cnt_prd['cum_percent']<50]
plt.figure(figsize=(20,10))

barplot = sns.barplot(data=cnt_prd_sub, x='product_name',y='frequency_count',hue=cnt_prd_sub['product_name'],dodge=False,palette = "hls")

for g in barplot.patches:
    barplot.annotate(format(g.get_height(), '.1f'),
                   (g.get_x() + g.get_width() / 2., g.get_height()),
                   ha = 'center', va = 'center',
                   xytext = (0, 9),
                   textcoords = 'offset points')

plt.ylabel('Number of Sales', fontsize=12)
plt.xlabel('Product Name', fontsize=12)
plt.title('Total Sales By product(over 50%)', fontsize = 22)
plt.xticks(rotation='vertical')

plt.show()

# %% [markdown]
# <b> Q 2. 상품군별 분석

# %%
cnt_prd_cls = train_past['category_name'].value_counts().reset_index()
cnt_prd_cls.columns = ['product_class', 'frequency_count']
cnt_prd_cls
# Out:
#                     product_class  frequency_count
# 0                    fresh fruits           501780
# 1                fresh vegetables           282838
# 2      packaged vegetables fruits           149855
# 3                            milk            57404
# 4   water seltzer sparkling water            41593
# 5                 packaged cheese            35362
# 6                     fresh herbs            26949
# 7                           cream            26499
# 8                 soy lactosefree            23722
# 9                packaged produce            13583
# 10                           eggs            13353
# 11           fresh dips tapenades            12781
# 12                 frozen produce            11506
# 13                         butter             9995
# 14                          bread             9083
# 15                   refrigerated             7739
# 16                  oils vinegars             7436
# 17                     lunch meat             6805
# 18             canned meals beans             6692
# 19               packaged poultry             6285
# 20                    soft drinks             2712

# %%
# 상품별 누적비중산출 
cnt_prd_cls['cum_percent'] = 100*(cnt_prd_cls['frequency_count'].cumsum() / cnt_prd_cls['frequency_count'].sum())


# 상품별 비중산출
cnt_prd_cls['percent'] = 100*(cnt_prd_cls['frequency_count'] / cnt_prd_cls['frequency_count'].sum())

cnt_prd_cls
# Out:
#                     product_class  frequency_count  cum_percent    percent
# 0                    fresh fruits           501780    40.015248  40.015248
# 1                fresh vegetables           282838    62.570616  22.555368
# 2      packaged vegetables fruits           149855    74.521042  11.950426
# 3                            milk            57404    79.098816   4.577774
# 4   water seltzer sparkling water            41593    82.415716   3.316900
# 5                 packaged cheese            35362    85.235715   2.819999
# 6                     fresh herbs            26949    87.384806   2.149091
# 7                           cream            26499    89.498011   2.113205
# 8                 soy lactosefree            23722    91.389760   1.891749
# 9                packaged produce            13583    92.472958   1.083198
# 10                           eggs            13353    93.537814   1.064856
# 11           fresh dips tapenades            12781    94.557056   1.019241
# 12                 frozen produce            11506    95.474620   0.917564
# 13                         butter             9995    96.271687   0.797067
# 14                          bread             9083    96.996025   0.724338
# 15                   refrigerated             7739    97.613184   0.617159
# 16                  oils vinegars             7436    98.206180   0.592996
# 17                     lunch meat             6805    98.748856   0.542676
# 18             canned meals beans             6692    99.282520   0.533664
# 19               packaged poultry             6285    99.783727   0.501207
# 20                    soft drinks             2712   100.000000   0.216273

# %%
cnt_prd_cls_sub=cnt_prd_cls.loc[cnt_prd_cls['cum_percent']<90]
plt.figure(figsize=(20,10))

barplot = sns.barplot(data=cnt_prd_cls_sub, x='product_class',y='frequency_count',hue=cnt_prd_cls_sub['product_class'],dodge=False,palette = "hls")

for g in barplot.patches:
    barplot.annotate(format(g.get_height(), '.1f'),
                   (g.get_x() + g.get_width() / 2., g.get_height()),
                   ha = 'center', va = 'center',
                   xytext = (0, 9),
                   textcoords = 'offset points')

plt.ylabel('Number of Sales', fontsize=12)
plt.xlabel('Product Class Name', fontsize=12)
plt.title('Total Sales By product class', fontsize = 22)
plt.xticks(rotation='vertical')

plt.show()

# %% [markdown]
# <b> Q 2. 부서별 분석

# %%
cnt_dept = train_past['division_name'].value_counts().reset_index()
cnt_dept.columns = ['department', 'frequency_count']
#cnt_dept.loc[:, "frequency_count"] = cnt_dept["frequency_count"].map('{:,d}'.format)

cnt_dept
# Out:
#      department  frequency_count
# 0       produce           975005
# 1    dairy eggs           166335
# 2     beverages            52044
# 3          deli            19586
# 4        frozen            11506
# 5        bakery             9083
# 6        pantry             7436
# 7  canned goods             6692
# 8  meat seafood             6285

# %%
# 부서별 누적비중산출 
cnt_dept['cum_percent'] = 100*(cnt_dept['frequency_count'].cumsum() / cnt_dept['frequency_count'].sum())


# 부서별 비중산출
cnt_dept['percent'] = 100*(cnt_dept['frequency_count'] / cnt_dept['frequency_count'].sum())

cnt_dept
# Out:
#      department  frequency_count  cum_percent    percent
# 0       produce           975005    77.753331  77.753331
# 1    dairy eggs           166335    91.017981  13.264650
# 2     beverages            52044    95.168313   4.150332
# 3          deli            19586    96.730230   1.561917
# 4        frozen            11506    97.647794   0.917564
# 5        bakery             9083    98.372133   0.724338
# 6        pantry             7436    98.965128   0.592996
# 7  canned goods             6692    99.498793   0.533664
# 8  meat seafood             6285   100.000000   0.501207

# %%
cnt_dept_sub=cnt_dept.loc[cnt_dept['cum_percent']<=100]
plt.figure(figsize=(20,10))

barplot = sns.barplot(data=cnt_dept_sub, x='department',y='frequency_count',hue=cnt_dept_sub['department'],dodge=False,palette = "hls")

for g in barplot.patches:
    barplot.annotate(format(g.get_height(), '.1f'),
                   (g.get_x() + g.get_width() / 2., g.get_height()),
                   ha = 'center', va = 'center',
                   xytext = (0, 9),
                   textcoords = 'offset points')

plt.ylabel('Number of Sales', fontsize=12)
plt.xlabel('Department Name', fontsize=12)
plt.title('Total Sales By department', fontsize = 22)
plt.xticks(rotation='vertical')

plt.show()

# %%
plt.figure(figsize=(10,10))
temp_series = train_past['division_name'].value_counts()
labels = (np.array(temp_series.index))
sizes = (np.array((temp_series / temp_series.sum())*100))
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()

# %% [markdown]
# #### 1.3.2 판매된 상품 요일 및 시간 분석

# %% [markdown]
# ### Day of Week

# %%
def day_week(row):
    if row['week_day'] == '0':
        return 'Sun'
    elif row['week_day'] == '1':
        return 'Mon'    
    elif row['week_day'] == '2':
        return 'Tue'
    elif row['week_day'] == '3':
        return 'Wed'    
    elif row['week_day'] == '4':
        return 'Thu'    
    elif row['week_day'] == '5':
        return 'Fri'    
    return 'Sat'
    
train_past['day_week_name']= train_past.apply(day_week,axis=1)
    
train_past
# Out:
#         order_id   cstno order_number week_day order_hour order_interval  \
# 0         717029  196613           15        1          9            3.0
# 1        2325772  196613           35        6         11            2.0
# 2          71041   32780           26        6         14            1.0
# 3        1265600   65610           29        5         13           12.0
# 4        1338494   65610           37        3         19            3.0
# ...          ...     ...          ...      ...        ...            ...
# 1253967  3396218   98204           30        5          8            7.0
# 1253968   432471  163746           33        5          7            5.0
# 1253969  1822814  163746           31        5          8           19.0
# 1253970  3160609  196534           31        6         13            4.0
# 1253971    71274  163782           16        0         12            5.0
#
#         add_order is_reordered product_id             product_name  \
# 0               5            0      41220  Organic Romaine Lettuce
# 1               7            1      41220  Organic Romaine Lettuce
# 2               1            0      41220  Organic Romaine Lettuce
# 3               3            1      41220  Organic Romaine Lettuce
# 4               2            1      41220  Organic Romaine Lettuce
# ...           ...          ...        ...                      ...
# 1253967         2            1      11520      Large Alfresco Eggs
# 1253968         1            1      11520      Large Alfresco Eggs
# 1253969         2            0      11520      Large Alfresco Eggs
# 1253970        11            0      11520      Large Alfresco Eggs
# 1253971         1            0      11520      Large Alfresco Eggs
#
#         category_id division_id     category_name division_name day_week_name
# 0                83           4  fresh vegetables       produce           Mon
# 1                83           4  fresh vegetables       produce           Sat
# 2                83           4  fresh vegetables       produce           Sat
# 3                83           4  fresh vegetables       produce           Fri
# 4                83           4  fresh vegetables       produce           Wed
# ...             ...         ...               ...           ...           ...
# 1253967          86          16              eggs    dairy eggs           Fri
# 1253968          86          16              eggs    dairy eggs           Fri
# 1253969          86          16              eggs    dairy eggs           Fri
# 1253970          86          16              eggs    dairy eggs           Sat
# 1253971          86          16              eggs    dairy eggs           Sun
#
# [1253972 rows x 15 columns]

# %%
cnt_week = train_past.groupby(['product_id','day_week_name'])['order_id'].count().reset_index(name='Sales_Number')

cnt_week_sum=cnt_week.groupby('day_week_name')['Sales_Number'].sum().reset_index(name='Sales_Sum')
cnt_week_sum['day_week_name']=pd.Categorical(cnt_week_sum['day_week_name'],categories=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
cnt_week_sum=cnt_week_sum.sort_values('day_week_name')


cnt_week_sum
# Out:
#   day_week_name  Sales_Sum
# 1           Mon     223454
# 5           Tue     157744
# 6           Wed     148008
# 4           Thu     151015
# 0           Fri     173503
# 2           Sat     167028
# 3           Sun     233220

# %%
plt.figure(figsize=(20,10))

barplot = sns.barplot(data=cnt_week_sum, x='day_week_name',y='Sales_Sum',hue=cnt_week_sum['day_week_name'],dodge=False,palette = "hls")

for g in barplot.patches:
    barplot.annotate(format(g.get_height(), '.1f'),
                   (g.get_x() + g.get_width() / 2., g.get_height()),
                   ha = 'center', va = 'center',
                   xytext = (0, 9),
                   textcoords = 'offset points')

plt.ylabel('Number of order', fontsize=12)
plt.xlabel('Week Name', fontsize=12)
plt.title('Total Order  By week', fontsize = 22)
plt.xticks(rotation='vertical')

plt.show()

# %%
order_product_cnt  = train_past.groupby('order_id').count()[['product_id']]
order_product_cnt.columns = ['product_cnt']
order_ds = train_past.merge(order_product_cnt, left_on = 'order_id',right_index =True)

# %%
def drawWeekhour(ds, values, aggfunc=len, title=None,figsize=(20,15), cmap=None):
    weekhour_ds= ds.pivot_table(index= 'week_day', columns = 'order_hour', values=values, aggfunc = aggfunc).fillna(0)
    sns.set(style="white",palette="colorblind", font_scale=1, rc={'font.family':'NanumGothic'})
    
    plt.figure(figsize=figsize)
    f = sns.heatmap(weekhour_ds, annot=True, fmt= "1.1f", linewidths=.3, cmap=cmap)
    plt.xlabel("Hour")
    plt.ylabel("Day of Week")
    if title:
        plt.title(title,fontsize=15)

# %%
drawWeekhour(order_ds, values = 'order_id',title= "Total Order Freq", aggfunc = lambda x:len(x)/1000)

# %%
train_x_past.loc[train_x_past['order_id']=='717029']
# Out:
#    order_id   cstno order_number week_day order_hour order_interval add_order  \
# 0    717029  196613           15        1          9            3.0         5
# 97   717029  196613           15        1          9            3.0         7
#
#    is_reordered product_id
# 0             0      41220
# 97            1      44359

# %%
print(train_x_past.loc[train_x_past['cstno']=='196613'])
# Out:
#     order_id   cstno order_number week_day order_hour order_interval  \
# 0     717029  196613           15        1          9            3.0
# 1    2325772  196613           35        6         11            2.0
# 2     642668  196613           69        2         16            2.0
# 3    1326515  196613           61        3         19            3.0
# 4    1437845  196613           36        3         15            4.0
# ..       ...     ...          ...      ...        ...            ...
# 198  2919366  196613           89        4         10            3.0
# 199  2948577  196613           25        5         18            7.0
# 200  2978591  196613           82        6         17            0.0
# 201  3193705  196613           55        3         17            0.0
# 202  3329257  196613           42        6         14            3.0
#
#     add_order is_reordered product_id
# 0           5            0      41220
# 1           7            1      41220
# 2          11            1       4210
# 3           3            1       4210
# 4          16            0       4210
# ..        ...          ...        ...
# 198         2            1      24852
# 199         5            1      24852
# 200        17            1      24852
# 201        12            1      24852
# 202        10            1      24852
#
# [203 rows x 9 columns]

# %%
train_x_current.loc[train_x_current['cstno']=='196613']
# Out:
#       order_id   cstno order_number week_day order_hour order_interval  \
# 1632   2414402  196613          100        6         13            5.0
# 24170  2414402  196613          100        6         13            5.0
#
#       add_order is_reordered
# 1632          4            1
# 24170         1            1

# %%
train_x_current.loc[train_x_current['is_reordered']=='1']
# Out:
#       order_id   cstno order_number week_day order_hour order_interval  \
# 0       806422   41116           47        5         18            3.0
# 1      2146033  127113           45        1         10            7.0
# 2      3055498  140168           45        5         10           26.0
# 3      3267527   60604           52        0         16            8.0
# 6       879062  138549           50        5         16            7.0
# ...        ...     ...          ...      ...        ...            ...
# 24419  3184000  174046          100        5          7            2.0
# 24420  1754722    6710          100        5         11            3.0
# 24421  1076973  150840          100        0         13            0.0
# 24422  1247049   99707          100        1         13            3.0
# 24423  1775787  201038          100        5          9            2.0
#
#       add_order is_reordered
# 0             4            1
# 1            24            1
# 2            11            1
# 3             2            1
# 6             4            1
# ...         ...          ...
# 24419        12            1
# 24420        21            1
# 24421        18            1
# 24422         6            1
# 24423         1            1
#
# [22987 rows x 8 columns]

# %%
train_x_past.loc[train_x_past['order_number']=='15']
# Out:
#         order_id   cstno order_number week_day order_hour order_interval  \
# 0         717029  196613           15        1          9            3.0
# 97        717029  196613           15        1          9            3.0
# 269      2417843   32775           15        2          6            3.0
# 324      2417843   32775           15        2          6            3.0
# 546       201756  131089           15        0         15            0.0
# ...          ...     ...          ...      ...        ...            ...
# 1253777  1525654  163819           15        1         11            7.0
# 1253816  1525654  163819           15        1         11            7.0
# 1253827  1525654  163819           15        1         11            7.0
# 1253843  1525654  163819           15        1         11            7.0
# 1253932  1525654  163819           15        1         11            7.0
#
#         add_order is_reordered product_id
# 0               5            0      41220
# 97              7            1      44359
# 269             2            1      33731
# 324             1            0      21616
# 546             1            1      33731
# ...           ...          ...        ...
# 1253777         2            1      43122
# 1253816        14            1       5077
# 1253827         4            1      41950
# 1253843         7            1      27086
# 1253932         3            1      47209
#
# [18630 rows x 9 columns]

# %%
cnt_dept_sub=cnt_dept.loc[cnt_dept['cum_percent']<=100]

# %%
# Out:
#   File "<ipython-input-50-e3516425615d>", line 1
#     train_x_past['order_id'='717029']
#                            ^
# SyntaxError: invalid syntax

# %%
train_x_past.head()
# Out:
#   order_id   cstno order_number week_day order_hour order_interval add_order  \
# 0   717029  196613           15        1          9            3.0         5
# 1  2325772  196613           35        6         11            2.0         7
# 2   642668  196613           69        2         16            2.0        11
# 3  1326515  196613           61        3         19            3.0         3
# 4  1437845  196613           36        3         15            4.0        16
#
#   is_reordered product_id
# 0            0      41220
# 1            1      41220
# 2            1       4210
# 3            1       4210
# 4            0       4210

# %%
cnt_dept_sub=cnt_dept.loc[cnt_dept['cum_percent']<=100]
cnt_dept_sub
# Out:
#      department  frequency_count  cum_percent    percent
# 0       produce           975005    77.753331  77.753331
# 1    dairy eggs           166335    91.017981  13.264650
# 2     beverages            52044    95.168313   4.150332
# 3          deli            19586    96.730230   1.561917
# 4        frozen            11506    97.647794   0.917564
# 5        bakery             9083    98.372133   0.724338
# 6        pantry             7436    98.965128   0.592996
# 7  canned goods             6692    99.498793   0.533664
# 8  meat seafood             6285   100.000000   0.501207

# %%
df1['row_number_by_group']=df1.groupby(['product'])['sales'].cumcount()+1

# %%
train_x_current
# Out:
#       order_id   cstno order_number week_day order_hour order_interval  \
# 0       806422   41116           47        5         18            3.0
# 1      2146033  127113           45        1         10            7.0
# 2      3055498  140168           45        5         10           26.0
# 3      3267527   60604           52        0         16            8.0
# 4      3125992  136554           46        4          9            5.0
# ...        ...     ...          ...      ...        ...            ...
# 24419  3184000  174046          100        5          7            2.0
# 24420  1754722    6710          100        5         11            3.0
# 24421  1076973  150840          100        0         13            0.0
# 24422  1247049   99707          100        1         13            3.0
# 24423  1775787  201038          100        5          9            2.0
#
#       add_order is_reordered
# 0             4            1
# 1            24            1
# 2            11            1
# 3             2            1
# 4             2            0
# ...         ...          ...
# 24419        12            1
# 24420        21            1
# 24421        18            1
# 24422         6            1
# 24423         1            1
#
# [24424 rows x 8 columns]

# %%
train_x_current['new_add_order'] = train_x_current.groupby(['product_id','day_week_name'])['order_id'].

# %%
train_x_current
